# %%
#import packages
import os
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

ini_data = pd.ExcelFile('DATA_VKR_FIN.xlsx')
df = ini_data.parse('Fin_Data')

# %%
#отбираем только оставшиеся после IV 17 фин коэффициентов
findata = df[['ROA', 'Eq_TA', 'Cash_TA', 'Pretax_margin', 'S_TA', 
             'ROCE', 'GPM', 'EBIT_IntEx', 'Cur_rat', 'ROE', 'lnTA', 'Eq_TL',
             'CFO_OperPr', 'CFO_S', 'ShtDebt_Eq', 'D_EBIT']]
findata
# Out:
#           ROA     Eq_TA   Cash_TA  Pretax_margin       S_TA        ROCE  \
# 0    0.068348  0.717348  0.018795       0.034251   1.584598    0.087232
# 1    0.105956  0.689469  0.067451       0.092864   1.444532    0.147199
# 2   -0.092264  0.478085  0.024046      -0.047342   1.088550   -0.174795
# 3    0.119885  0.476917  0.002983       0.142394   1.117112    0.217434
# 4   -0.016428  0.126975  0.005281      -0.012054   0.658542   -0.082351
# 5   -0.043086 -0.096067  0.000529      -0.124859   0.409897   -0.059081
# 6   -0.015995 -0.114521  0.000753      -0.046832   0.396896   -0.023593
# 7   -0.016859 -0.130225  0.012796      -0.044882   0.453434   -0.021456
# 8    0.024344 -0.027702  0.025451       0.067472   0.416878    0.025444
# 9    0.016498  0.034282  0.014578       0.048709   0.437730    0.019291
# 10   0.768650  0.498023  0.173932       0.257433   3.012206    1.245530
# 11   0.187448  0.585508  0.026754       0.204992   1.046927    0.293105
# ...

# %%
#находим значение 5 квантиля

quant5_1 = findata['ROA'].quantile(0.05, interpolation = 'lower')
quant5_2 = findata['Eq_TA'].quantile(0.05, interpolation = 'lower')
quant5_3 = findata['Cash_TA'].quantile(0.05, interpolation = 'lower')
quant5_4 = findata['Pretax_margin'].quantile(0.05, interpolation = 'lower')
quant5_5 = findata['S_TA'].quantile(0.05, interpolation = 'lower')
quant5_6 = findata['ROCE'].quantile(0.05, interpolation = 'lower')
quant5_7 = findata['GPM'].quantile(0.05, interpolation = 'lower')
quant5_8 = findata['EBIT_IntEx'].quantile(0.05, interpolation = 'lower')
quant5_9 = findata['Cur_rat'].quantile(0.05, interpolation = 'lower')
quant5_10 = findata['ROE'].quantile(0.05, interpolation = 'lower')
quant5_11 = findata['lnTA'].quantile(0.05, interpolation = 'lower')
quant5_12 = findata['Eq_TL'].quantile(0.05, interpolation = 'lower')
quant5_13 = findata['CFO_OperPr'].quantile(0.05, interpolation = 'lower')
quant5_14 = findata['CFO_S'].quantile(0.05, interpolation = 'lower')
quant5_15 = findata['ShtDebt_Eq'].quantile(0.05, interpolation = 'lower')
#quant5_16 = findata['Tan_TA'].quantile(0.05, interpolation = 'lower')
quant5_17 = findata['D_EBIT'].quantile(0.05, interpolation = 'lower')

# %%
#заменяем нижние выбросы в findata на 5 квантиль
import warnings
warnings.filterwarnings('ignore')

findata['ROA'].loc[findata['ROA'] < quant5_1] = quant5_1
findata['Eq_TA'].loc[findata['Eq_TA'] < quant5_2] = quant5_2
findata['Cash_TA'].loc[findata['Cash_TA'] < quant5_3] = quant5_3
findata['Pretax_margin'].loc[findata['Pretax_margin'] < quant5_4] = quant5_4
findata['S_TA'].loc[findata['S_TA'] < quant5_5] = quant5_5
findata['ROCE'].loc[findata['ROCE'] < quant5_6] = quant5_6
findata['GPM'].loc[findata['GPM'] < quant5_7] = quant5_7
findata['EBIT_IntEx'].loc[findata['EBIT_IntEx'] < quant5_8] = quant5_8
findata['Cur_rat'].loc[findata['Cur_rat'] < quant5_9] = quant5_9
findata['ROE'].loc[findata['ROE'] < quant5_10] = quant5_10
findata['lnTA'].loc[findata['lnTA'] < quant5_11] = quant5_11
findata['Eq_TL'].loc[findata['Eq_TL'] < quant5_12] = quant5_12
findata['CFO_OperPr'].loc[findata['CFO_OperPr'] < quant5_13] = quant5_13
findata['CFO_S'].loc[findata['CFO_S'] < quant5_14] = quant5_14
findata['ShtDebt_Eq'].loc[findata['ShtDebt_Eq'] < quant5_15] = quant5_15
#findata['Tan_TA'].loc[findata['Tan_TA'] < quant5_16] = quant5_16
findata['D_EBIT'].loc[findata['D_EBIT'] < quant5_17] = quant5_17

# %%
#находим значение 95 квантиля

quant95_1 = findata['ROA'].quantile(0.95, interpolation = 'higher')
quant95_2 = findata['Eq_TA'].quantile(0.95, interpolation = 'higher')
quant95_3 = findata['Cash_TA'].quantile(0.95, interpolation = 'higher')
quant95_4 = findata['Pretax_margin'].quantile(0.95, interpolation = 'higher')
quant95_5 = findata['S_TA'].quantile(0.95, interpolation = 'higher')
quant95_6 = findata['ROCE'].quantile(0.95, interpolation = 'higher')
quant95_7 = findata['GPM'].quantile(0.95, interpolation = 'higher')
quant95_8 = findata['EBIT_IntEx'].quantile(0.95, interpolation = 'higher')
quant95_9 = findata['Cur_rat'].quantile(0.95, interpolation = 'higher')
quant95_10 = findata['ROE'].quantile(0.95, interpolation = 'higher')
quant95_11 = findata['lnTA'].quantile(0.95, interpolation = 'higher')
quant95_12 = findata['Eq_TL'].quantile(0.95, interpolation = 'higher')
quant95_13 = findata['CFO_OperPr'].quantile(0.95, interpolation = 'higher')
quant95_14 = findata['CFO_S'].quantile(0.95, interpolation = 'higher')
quant95_15 = findata['ShtDebt_Eq'].quantile(0.95, interpolation = 'higher')
#quant95_16 = findata['Tan_TA'].quantile(0.95, interpolation = 'higher')
quant95_17 = findata['D_EBIT'].quantile(0.95, interpolation = 'higher')

# %%
#заменяем верхние выбросы в findata на 95 квантиль

findata['ROA'].loc[findata['ROA'] > quant95_1] = quant95_1
findata['Eq_TA'].loc[findata['Eq_TA'] > quant95_2] = quant95_2
findata['Cash_TA'].loc[findata['Cash_TA'] > quant95_3] = quant95_3
findata['Pretax_margin'].loc[findata['Pretax_margin'] > quant95_4] = quant95_4
findata['S_TA'].loc[findata['S_TA'] > quant95_5] = quant95_5
findata['ROCE'].loc[findata['ROCE'] > quant95_6] = quant95_6
findata['GPM'].loc[findata['GPM'] > quant95_7] = quant95_7
findata['EBIT_IntEx'].loc[findata['EBIT_IntEx'] > quant95_8] = quant95_8
findata['Cur_rat'].loc[findata['Cur_rat'] > quant95_9] = quant95_9
findata['ROE'].loc[findata['ROE'] > quant95_10] = quant95_10
findata['lnTA'].loc[findata['lnTA'] > quant95_11] = quant95_11
findata['Eq_TL'].loc[findata['Eq_TL'] > quant95_12] = quant95_12
findata['CFO_OperPr'].loc[findata['CFO_OperPr'] > quant95_13] = quant95_13
findata['CFO_S'].loc[findata['CFO_S'] > quant95_14] = quant95_14
findata['ShtDebt_Eq'].loc[findata['ShtDebt_Eq'] > quant95_15] = quant95_15
#findata['Tan_TA'].loc[findata['Tan_TA'] > quant95_16] = quant95_16
findata['D_EBIT'].loc[findata['D_EBIT'] > quant95_17] = quant95_17

# %%
#Расчет граничных значений фин коэффициентов

mindata = findata.min()
mindata = mindata.to_frame()
mindata = mindata.rename(columns={0: "X_min"})

maxdata = findata.max()
maxdata = maxdata.to_frame()
maxdata = maxdata.rename(columns={0: "X_max"})

meandata = findata.mean()
meandata = meandata.to_frame()
meandata = meandata.rename(columns={0: "X_mean"})

stddata = findata.std()
stddata = stddata.to_frame()
stddata = stddata.rename(columns={0: "X_std"})

boundaries = pd.concat([mindata, maxdata, meandata, stddata], axis = 1)
boundaries
# Out:
#                   X_min      X_max     X_mean      X_std
# ROA           -0.146838   0.288912   0.048789   0.100910
# Eq_TA         -0.392175   0.834279   0.241626   0.314541
# Cash_TA        0.000000   0.238606   0.039236   0.063707
# Pretax_margin -0.250406   0.271185   0.029504   0.108562
# S_TA           0.000000   6.598298   1.789115   1.769587
# ROCE          -0.233388   0.834661   0.149043   0.256872
# GPM           -0.008882   0.591441   0.180276   0.175444
# EBIT_IntEx    -4.619558  72.578947   6.627360  17.411775
# Cur_rat        0.000000   6.260637   1.663850   1.574531
# ROE           -0.357145   1.432477   0.247566   0.427049
# lnTA           0.000000  23.211759  18.244853   6.988791
# Eq_TL         -0.272175  10.938738   1.251860   2.743435
# CFO_OperPr    -5.371483   6.146644   0.359639   2.349810
# CFO_S         -0.223747   0.321359   0.037496   0.122221
# ShtDebt_Eq    -1.239756   7.138035   0.761497   1.865104
# ...

# %%
#создаем копию findata для конечного нормирования значений
findata_copy = df[['ROA', 'Eq_TA', 'Cash_TA', 'Pretax_margin', 'S_TA', 
             'ROCE', 'GPM', 'EBIT_IntEx', 'Cur_rat', 'ROE', 'lnTA', 'Eq_TL',
             'CFO_OperPr', 'CFO_S', 'ShtDebt_Eq', 'D_EBIT']]
findata_copy
# Out:
#           ROA     Eq_TA   Cash_TA  Pretax_margin       S_TA        ROCE  \
# 0    0.068348  0.717348  0.018795       0.034251   1.584598    0.087232
# 1    0.105956  0.689469  0.067451       0.092864   1.444532    0.147199
# 2   -0.092264  0.478085  0.024046      -0.047342   1.088550   -0.174795
# 3    0.119885  0.476917  0.002983       0.142394   1.117112    0.217434
# 4   -0.016428  0.126975  0.005281      -0.012054   0.658542   -0.082351
# 5   -0.043086 -0.096067  0.000529      -0.124859   0.409897   -0.059081
# 6   -0.015995 -0.114521  0.000753      -0.046832   0.396896   -0.023593
# 7   -0.016859 -0.130225  0.012796      -0.044882   0.453434   -0.021456
# 8    0.024344 -0.027702  0.025451       0.067472   0.416878    0.025444
# 9    0.016498  0.034282  0.014578       0.048709   0.437730    0.019291
# 10   0.768650  0.498023  0.173932       0.257433   3.012206    1.245530
# 11   0.187448  0.585508  0.026754       0.204992   1.046927    0.293105
# ...

# %%
#Нормировка значений
#1 ROA
findata_copy['ROA'].loc[findata_copy['ROA'] >= findata['ROA'].max()] = 10
findata_copy['ROA'].loc[findata_copy['ROA'] <= findata['ROA'].min()] = 0
findata_copy['ROA'].loc[(findata_copy['ROA'] != 10)&(findata_copy['ROA'] != 0)] = (5/2)*((findata_copy['ROA']-findata['ROA'].mean())/findata['ROA'].std())+5

#2 Eq_TA
findata_copy['Eq_TA'].loc[findata_copy['Eq_TA'] >= findata['Eq_TA'].max()] = 10
findata_copy['Eq_TA'].loc[findata_copy['Eq_TA'] <= findata['Eq_TA'].min()] = 0
findata_copy['Eq_TA'].loc[(findata_copy['Eq_TA'] != 10)&(findata_copy['Eq_TA'] != 0)] = (5/2)*((findata_copy['Eq_TA']-findata['Eq_TA'].mean())/findata['Eq_TA'].std())+5

#3 Cash_TA
findata_copy['Cash_TA'].loc[findata_copy['Cash_TA'] >= findata['Cash_TA'].max()] = 10
findata_copy['Cash_TA'].loc[findata_copy['Cash_TA'] <= findata['Cash_TA'].min()] = 0
findata_copy['Cash_TA'].loc[(findata_copy['Cash_TA'] != 10)&(findata_copy['Cash_TA'] != 0)] = (5/2)*((findata_copy['Cash_TA']-findata['Cash_TA'].mean())/findata['Cash_TA'].std())+5

#4 Pretax_margin
findata_copy['Pretax_margin'].loc[findata_copy['Pretax_margin'] >= findata['Pretax_margin'].max()] = 10
findata_copy['Pretax_margin'].loc[findata_copy['Pretax_margin'] <= findata['Pretax_margin'].min()] = 0
findata_copy['Pretax_margin'].loc[(findata_copy['Pretax_margin'] != 10)&(findata_copy['Pretax_margin'] != 0)] = (5/2)*((findata_copy['Pretax_margin']-findata['Pretax_margin'].mean())/findata['Pretax_margin'].std())+5

#5 S_TA
findata_copy['S_TA'].loc[findata_copy['S_TA'] >= findata['S_TA'].max()] = 10
findata_copy['S_TA'].loc[findata_copy['S_TA'] <= findata['S_TA'].min()] = 0
findata_copy['S_TA'].loc[(findata_copy['S_TA'] != 10)&(findata_copy['S_TA'] != 0)] = (5/2)*((findata_copy['S_TA']-findata['S_TA'].mean())/findata['S_TA'].std())+5

#6 ROCE
findata_copy['ROCE'].loc[findata_copy['ROCE'] >= findata['ROCE'].max()] = 10
findata_copy['ROCE'].loc[findata_copy['ROCE'] <= findata['ROCE'].min()] = 0
findata_copy['ROCE'].loc[(findata_copy['ROCE'] != 10)&(findata_copy['ROCE'] != 0)] = (5/2)*((findata_copy['ROCE']-findata['ROCE'].mean())/findata['ROCE'].std())+5

#7 GPM
findata_copy['GPM'].loc[findata_copy['GPM'] >= findata['GPM'].max()] = 10
findata_copy['GPM'].loc[findata_copy['GPM'] <= findata['GPM'].min()] = 0
findata_copy['GPM'].loc[(findata_copy['GPM'] != 10)&(findata_copy['GPM'] != 0)] = (5/2)*((findata_copy['GPM']-findata['GPM'].mean())/findata['GPM'].std())+5

#8 EBIT_IntEx
findata_copy['EBIT_IntEx'].loc[findata_copy['EBIT_IntEx'] >= findata['EBIT_IntEx'].max()] = 10
findata_copy['EBIT_IntEx'].loc[findata_copy['EBIT_IntEx'] <= findata['EBIT_IntEx'].min()] = 0
findata_copy['EBIT_IntEx'].loc[(findata_copy['EBIT_IntEx'] != 10)&(findata_copy['EBIT_IntEx'] != 0)] = (5/2)*((findata_copy['EBIT_IntEx']-findata['EBIT_IntEx'].mean())/findata['EBIT_IntEx'].std())+5

#9 Cur_rat
findata_copy['Cur_rat'].loc[findata_copy['Cur_rat'] >= findata['Cur_rat'].max()] = 10
findata_copy['Cur_rat'].loc[findata_copy['Cur_rat'] <= findata['Cur_rat'].min()] = 0
findata_copy['Cur_rat'].loc[(findata_copy['Cur_rat'] != 10)&(findata_copy['Cur_rat'] != 0)] = (5/2)*((findata_copy['Cur_rat']-findata['Cur_rat'].mean())/findata['Cur_rat'].std())+5

#10 ROE
findata_copy['ROE'].loc[findata_copy['ROE'] >= findata['ROE'].max()] = 10
findata_copy['ROE'].loc[findata_copy['ROE'] <= findata['ROE'].min()] = 0
findata_copy['ROE'].loc[(findata_copy['ROE'] != 10)&(findata_copy['ROE'] != 0)] = (5/2)*((findata_copy['ROE']-findata['ROE'].mean())/findata['ROE'].std())+5

#11 lnTA
findata_copy['lnTA'].loc[findata_copy['lnTA'] >= findata['lnTA'].max()] = 10
findata_copy['lnTA'].loc[findata_copy['lnTA'] <= findata['lnTA'].min()] = 0
findata_copy['lnTA'].loc[(findata_copy['lnTA'] != 10)&(findata_copy['lnTA'] != 0)] = (5/2)*((findata_copy['lnTA']-findata['lnTA'].mean())/findata['lnTA'].std())+5

#12 Eq_TL
findata_copy['Eq_TL'].loc[findata_copy['Eq_TL'] >= findata['Eq_TL'].max()] = 10
findata_copy['Eq_TL'].loc[findata_copy['Eq_TL'] <= findata['Eq_TL'].min()] = 0
findata_copy['Eq_TL'].loc[(findata_copy['Eq_TL'] != 10)&(findata_copy['Eq_TL'] != 0)] = (5/2)*((findata_copy['Eq_TL']-findata['Eq_TL'].mean())/findata['Eq_TL'].std())+5

#13 CFO_OperPr
findata_copy['CFO_OperPr'].loc[findata_copy['CFO_OperPr'] >= findata['CFO_OperPr'].max()] = 10
findata_copy['CFO_OperPr'].loc[findata_copy['CFO_OperPr'] <= findata['CFO_OperPr'].min()] = 0
findata_copy['CFO_OperPr'].loc[(findata_copy['CFO_OperPr'] != 10)&(findata_copy['CFO_OperPr'] != 0)] = (5/2)*((findata_copy['CFO_OperPr']-findata['CFO_OperPr'].mean())/findata['CFO_OperPr'].std())+5

#14 CFO_S
findata_copy['CFO_S'].loc[findata_copy['CFO_S'] >= findata['CFO_S'].max()] = 10
findata_copy['CFO_S'].loc[findata_copy['CFO_S'] <= findata['CFO_S'].min()] = 0
findata_copy['CFO_S'].loc[(findata_copy['CFO_S'] != 10)&(findata_copy['CFO_S'] != 0)] = (5/2)*((findata_copy['CFO_S']-findata['CFO_S'].mean())/findata['CFO_S'].std())+5

#15 ShtDebt_Eq
findata_copy['ShtDebt_Eq'].loc[findata_copy['ShtDebt_Eq'] >= findata['ShtDebt_Eq'].max()] = 10
findata_copy['ShtDebt_Eq'].loc[findata_copy['ShtDebt_Eq'] <= findata['ShtDebt_Eq'].min()] = 0
findata_copy['ShtDebt_Eq'].loc[(findata_copy['ShtDebt_Eq'] != 10)&(findata_copy['ShtDebt_Eq'] != 0)] = (5/2)*((findata_copy['ShtDebt_Eq']-findata['ShtDebt_Eq'].mean())/findata['ShtDebt_Eq'].std())+5

#16 Tan_TA
#findata_copy['Tan_TA'].loc[findata_copy['Tan_TA'] >= findata['Tan_TA'].max()] = 10
#findata_copy['Tan_TA'].loc[findata_copy['Tan_TA'] <= findata['Tan_TA'].min()] = 0
#findata_copy['Tan_TA'].loc[(findata_copy['Tan_TA'] != 10)&(findata_copy['Tan_TA'] != 0)] = (5/2)*((findata_copy['Tan_TA']-findata['Tan_TA'].mean())/findata['Tan_TA'].std())+5

#17 D_EBIT
findata_copy['D_EBIT'].loc[findata_copy['D_EBIT'] >= findata['D_EBIT'].max()] = 10
findata_copy['D_EBIT'].loc[findata_copy['D_EBIT'] <= findata['D_EBIT'].min()] = 0
findata_copy['D_EBIT'].loc[(findata_copy['D_EBIT'] != 10)&(findata_copy['D_EBIT'] != 0)] = (5/2)*((findata_copy['D_EBIT']-findata['D_EBIT'].mean())/findata['D_EBIT'].std())+5

# %%
#убираем значения больше 10 и меньше 0 после нормировки 
#1 - ROA
findata_copy['ROA'].loc[findata_copy['ROA'] < 0] = 0
findata_copy['ROA'].loc[findata_copy['ROA'] > 10] = 10
#2 - Eq_TA
findata_copy['Eq_TA'].loc[findata_copy['Eq_TA'] <= 0] = 0
findata_copy['Eq_TA'].loc[findata_copy['Eq_TA'] > 10] = 10
#3 - Cash_TA
findata_copy['Cash_TA'].loc[findata_copy['Cash_TA'] > 10] = 10
findata_copy['Cash_TA'].loc[findata_copy['Cash_TA'] <= 0] = 0
#4 - Pretax_margin
findata_copy['Pretax_margin'].loc[findata_copy['Pretax_margin'] > 10] = 10
findata_copy['Pretax_margin'].loc[findata_copy['Pretax_margin'] <= 0] = 0
#5 - S_TA
findata_copy['S_TA'].loc[findata_copy['S_TA'] > 10] = 10
findata_copy['S_TA'].loc[findata_copy['S_TA'] <= 0] = 0
#6 - ROCE
findata_copy['ROCE'].loc[findata_copy['ROCE'] > 10] = 10
findata_copy['ROCE'].loc[findata_copy['ROCE'] <= 0] = 0
#7 - GPM
findata_copy['GPM'].loc[findata_copy['GPM'] > 10] = 10
findata_copy['GPM'].loc[findata_copy['GPM'] <= 0] = 0
#8 - EBIT_IntEx
findata_copy['EBIT_IntEx'].loc[findata_copy['EBIT_IntEx'] > 10] = 10
findata_copy['EBIT_IntEx'].loc[findata_copy['EBIT_IntEx'] <= 0] = 0
#9 - Cur_rat
findata_copy['Cur_rat'].loc[findata_copy['Cur_rat'] > 10] = 10
findata_copy['Cur_rat'].loc[findata_copy['Cur_rat'] < 0] = 0
#10 - ROE
findata_copy['ROE'].loc[findata_copy['ROE'] > 10] = 10
findata_copy['ROE'].loc[findata_copy['ROE'] < 0] = 0
#11 - lnTA
findata_copy['lnTA'].loc[findata_copy['lnTA'] < 0] = 0
findata_copy['lnTA'].loc[findata_copy['lnTA'] > 10] = 10
#12 - Eq_TL
findata_copy['Eq_TL'].loc[findata_copy['Eq_TL'] < 0] = 0
findata_copy['Eq_TL'].loc[findata_copy['Eq_TL'] > 10] = 10
#13 - CFO_OperPr
findata_copy['CFO_OperPr'].loc[findata_copy['CFO_OperPr'] < 0] = 0
findata_copy['CFO_OperPr'].loc[findata_copy['CFO_OperPr'] > 10] = 10
#14 - CFO_S
findata_copy['CFO_S'].loc[findata_copy['CFO_S'] < 0] = 0
findata_copy['CFO_S'].loc[findata_copy['CFO_S'] > 10] = 10
#15 - ShtDebt_Eq
findata_copy['ShtDebt_Eq'].loc[findata_copy['ShtDebt_Eq'] < 0] = 0
findata_copy['ShtDebt_Eq'].loc[findata_copy['ShtDebt_Eq'] > 10] = 10
#16 - Tan_TA
#findata_copy['Tan_TA'].loc[findata_copy['Tan_TA'] < 0] = 0
#findata_copy['Tan_TA'].loc[findata_copy['Tan_TA'] > 10] = 10
#17 - D_EBIT
findata_copy['D_EBIT'].loc[findata_copy['D_EBIT'] < 0] = 0
findata_copy['D_EBIT'].loc[findata_copy['D_EBIT'] > 10] = 10

# %%
findata_copy.to_excel('FinRatios_NormData_FIN.xlsx')
